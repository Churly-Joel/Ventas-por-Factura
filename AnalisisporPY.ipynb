# %%
import pandas as pd
import seaborn  as sns

# %%
df=pd.read_csv("ventas-por-factura.csv")

# %%
df
# Out:
#       N° de factura     Fecha de factura  ID Cliente            País  \
# 0            548370   3/30/2021 16:14:00     15528.0  United Kingdom
# 1            575767  11/11/2021 11:11:00     17348.0  United Kingdom
# 2           C570727  10/12/2021 11:32:00     12471.0         Germany
# 3            549106    4/6/2021 12:08:00     17045.0  United Kingdom
# 4            573112  10/27/2021 15:33:00     16416.0  United Kingdom
# ...             ...                  ...         ...             ...
# 25948       C556518   6/13/2021 10:53:00     16794.0  United Kingdom
# 25949        553060   5/13/2021 10:44:00     15826.0  United Kingdom
# 25950        577049  11/17/2021 13:58:00     17397.0  United Kingdom
# 25951        550122   4/14/2021 12:39:00     12931.0  United Kingdom
# 25952        537999   12/9/2020 11:44:00         NaN  United Kingdom
#
#        Cantidad    Monto
# 0           123   229,33
# 1           163   209,73
# 2            -1    -1,45
# 3             1    39,95
# ...

# %%
import matplotlib.pyplot as plt

# %%
ax = df['Cantidad'].plot.hist(bins=10, figsize=(8, 12))
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
plt.title('Histograma de cantidades')
plt.show()

# %%
conteo_paises = df['País'].value_counts().reset_index()
conteo_paises.columns = ['País', 'Frecuencia']
print(conteo_paises)
# Out:
#                     País  Frecuencia
# 0         United Kingdom       23542
# 1                Germany         603
# 2                 France         462
# 3                   EIRE         362
# 4                Belgium         119
# 5                  Spain         105
# 6            Netherlands         101
# 7            Switzerland          74
# 8               Portugal          71
# 9              Australia          69
# 10                 Italy          55
# 11               Finland          48
# 12                Sweden          46
# 13                Norway          40
# 14       Channel Islands          34
# 15                 Japan          29
# 16                Poland          24
# 17               Denmark          21
# 18                Cyprus          20
# 19               Austria          19
# 20             Hong Kong          15
# 21           Unspecified          13
# 22                 Malta          10
# 23             Singapore          10
# ...

# %%
print(df.head())
# Out:
#   N° de factura     Fecha de factura  ID Cliente            País  Cantidad  \
# 0        548370   3/30/2021 16:14:00     15528.0  United Kingdom       123
# 1        575767  11/11/2021 11:11:00     17348.0  United Kingdom       163
# 2       C570727  10/12/2021 11:32:00     12471.0         Germany        -1
# 3        549106    4/6/2021 12:08:00     17045.0  United Kingdom         1
# 4        573112  10/27/2021 15:33:00     16416.0  United Kingdom       357
#
#     Monto
# 0  229,33
# 1  209,73
# 2   -1,45
# 3   39,95
# 4  344,83

# %%
maximos = df[['Cantidad', 'Monto']].max()
minimos = df[['Cantidad', 'Monto']].min()

# %%
print("\nMáximos:")
print(maximos)
print("\nMínimos:")
print(minimos)
# Out:
# Máximos:
# Cantidad     80995
# Monto       999,26
# dtype: object
#
# Mínimos:
# Cantidad    -80995
# Monto        -0,39
# dtype: object

# %%
sns.set(style="whitegrid")

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df[['Cantidad', 'Monto']].describe().loc[['mean', 'max', 'min']].T.plot(kind='bar', ax=ax)

ax.set_title('Estadísticas de Cantidad y Monto', fontsize=14)
ax.set_ylabel('Valor', fontsize=12)
ax.set_xlabel('Columnas', fontsize=12)
# Out:
# Text(0.5, 0, 'Columnas')
